# %% [markdown]
# # Tokenizers
#
# For this Colab session, we explore the world of Tokenizers
#
# You can run this notebook on a free CPU, or locally on your box if you prefer.

# %% [markdown]
# ## Reminder: 2 important pro-tips for using Colab:
#
# **Pro-tip 1:**
#
# Don't worry about warnings and messages!
#
# **Pro-tip 2:**
#
# In the middle of running a Colab, you might get an error like this:
#
# > Runtime error: CUDA is required but not available for bitsandbytes. Please consider installing [...]
#
# This is a super-misleading error message! Please don't try changing versions of packages...
#
# This actually happens because Google has switched out your Colab runtime, perhaps because Google Colab was too busy. The solution is:
#
# 1. Kernel menu >> Disconnect and delete runtime
# 2. Reload the colab from fresh and Edit menu >> Clear All Outputs
# 3. Connect to a new T4 using the button at the top right
# 4. Select "View resources" from the menu on the top right to confirm you have a GPU
# 5. Rerun the cells in the colab, from the top down, starting with the pip installs
#
# And all should work great - otherwise, ask me!

# %%
from google.colab import userdata
from huggingface_hub import login
from transformers import AutoTokenizer

# %% [markdown]
# # Sign in to Hugging Face
#
# 1. If you haven't already done so, create a free HuggingFace account at https://huggingface.co and navigate to Settings, then Create a new API token, giving yourself write permissions
#
# **IMPORTANT** when you create your HuggingFace API key, please be sure to select read/write permissions for your key by clicking on the WRITE tab, otherwise you may get problems later.
#
# 2. Press the "key" icon on the side panel to the left, and add a new secret:
# `HF_TOKEN = your_token`
#
# 3. Execute the cell below to log in.

# %%
# Log in to Hugging Face

hf_token = userdata.get('HF_TOKEN')
if hf_token and hf_token.startswith("hf_"):
  print("HF key looks good so far")
else:
  print("HF key is not set - please click the key in the left sidebar")
login(hf_token, add_to_git_credential=True)

# Check Google Colab GPU

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
  if gpu_info.find('Tesla T4') >= 0:
    print("Success - Connected to a T4")
  else:
    print("NOT CONNECTED TO A T4")
# Out:
# HF key looks good so far
# Wed Nov 12 20:57:24 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Success - Connected to a T4

# %% [markdown]
# # Accessing Llama 3.1 from Meta
#
# In order to use the fantastic Llama 3.1, Meta does require you to sign their terms of service.
#
# Visit their model instructions page in Hugging Face:
# https://huggingface.co/meta-llama/Meta-Llama-3.1-8B
#
# At the top of the page are instructions on how to agree to their terms. If possible, you should use the same email as your huggingface account.
#
# In my experience approval comes in a couple of minutes. Once you've been approved for any 3.1 model, it applies to the whole 3.1 family of models. For whatever reason, occasionally Meta doesn't approve access. If that happens to you, please follow [this](https://colab.research.google.com/drive/1deJO03YZTXUwcq2vzxWbiBhrRuI29Vo8?usp=sharing) troubleshooting.
#
# If the next cell gives you an error, then please check:
# 1. Are you logged in to HuggingFace? Try running `login()` to check your key works
# 2. Did you set up your API key with full read and write permissions?
# 3. If you visit the Llama3.1 page with the link above, does it show that you have access to the model near the top?
#
# I've also set up this troubleshooting colab to try to diagnose any HuggingFace connectivity issues:
# https://colab.research.google.com/drive/1deJO03YZTXUwcq2vzxWbiBhrRuI29Vo8?usp=sharing

# %%
tokenizer = AutoTokenizer.from_pretrained('meta-llama/Llama-4-Scout-17B-16E-Instruct', trust_remote_code=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/27.9M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/3.62M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/106 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/7.35k [00:00<?, ?B/s]

# %%
text = "I am excited to show Tokenizers in action to my LLM engineers"
tokens = tokenizer.encode(text)
tokens
# Out:
# [200000,
#  53,
#  1045,
#  26095,
#  328,
#  2655,
#  19736,
#  26302,
#  310,
#  4245,
#  328,
#  1626,
#  163636,
#  48556]

# %%
character_count = len(text)
word_count = len(text.split(' '))
token_count = len(tokens)
print(f"There are {character_count} characters, {word_count} words and {token_count} tokens")
# Out:
# There are 61 characters, 12 words and 14 tokens

# %%
tokenizer.decode(tokens)
# Out:
# '<|begin_of_text|>I am excited to show Tokenizers in action to my LLM engineers'

# %%
tokenizer.batch_decode(tokens)
# Out:
# ['<|begin_of_text|>',
#  'I',
#  ' am',
#  ' excited',
#  ' to',
#  ' show',
#  ' Token',
#  'izers',
#  ' in',
#  ' action',
#  ' to',
#  ' my',
#  ' LLM',
#  ' engineers']

# %%
# tokenizer.vocab
tokenizer.get_added_vocab()
# Out:
# {'<|begin_of_text|>': 200000,
#  '<|end_of_text|>': 200001,
#  '<|fim_prefix|>': 200002,
#  '<|fim_middle|>': 200003,
#  '<|fim_suffix|>': 200004,
#  '<|header_start|>': 200005,
#  '<|header_end|>': 200006,
#  '<|eom|>': 200007,
#  '<|eot|>': 200008,
#  '<|step|>': 200009,
#  '<|text_post_train_reserved_special_token_0|>': 200010,
#  '<|text_post_train_reserved_special_token_1|>': 200011,
#  '<|text_post_train_reserved_special_token_2|>': 200012,
#  '<|text_post_train_reserved_special_token_3|>': 200013,
#  '<|text_post_train_reserved_special_token_4|>': 200014,
#  '<|text_post_train_reserved_special_token_5|>': 200015,
#  '<|python_start|>': 200016,
#  '<|python_end|>': 200017,
#  '<|finetune_right_pad|>': 200018,
#  '<|text_post_train_reserved_special_token_6|>': 200019,
#  '<|text_post_train_reserved_special_token_7|>': 200020,
#  '<|text_post_train_reserved_special_token_8|>': 200021,
#  '<|text_post_train_reserved_special_token_9|>': 200022,
#  '<|text_post_train_reserved_special_token_10|>': 200023,
#  '<|text_post_train_reserved_special_token_11|>': 200024,
#  '<|text_post_train_reserved_special_token_12|>': 200025,
#  '<|text_post_train_reserved_special_token_13|>': 200026,
#  '<|text_post_train_reserved_special_token_14|>': 200027,
#  '<|text_post_train_reserved_special_token_15|>': 200028,
#  '<|text_post_train_reserved_special_token_16|>': 200029,
#  '<|text_post_train_reserved_special_token_17|>': 200030,
#  '<|text_post_train_reserved_special_token_18|>': 200031,
#  '<|text_post_train_reserved_special_token_19|>': 200032,
#  '<|text_post_train_reserved_special_token_20|>': 200033,
#  '<|text_post_train_reserved_special_token_21|>': 200034,
#  '<|text_post_train_reserved_special_token_22|>': 200035,
#  '<|text_post_train_reserved_special_token_23|>': 200036,
#  '<|text_post_train_reserved_special_token_24|>': 200037,
#  '<|text_post_train_reserved_special_token_25|>': 200038,
#  '<|text_post_train_reserved_special_token_26|>': 200039,
#  '<|text_post_train_reserved_special_token_27|>': 200040,
#  '<|text_post_train_reserved_special_token_28|>': 200041,
#  '<|text_post_train_reserved_special_token_29|>': 200042,
#  '<|text_post_train_reserved_special_token_30|>': 200043,
#  '<|text_post_train_reserved_special_token_31|>': 200044,
#  '<|text_post_train_reserved_special_token_32|>': 200045,
#  '<|text_post_train_reserved_special_token_33|>': 200046,
#  '<|text_post_train_reserved_special_token_34|>': 200047,
#  '<|text_post_train_reserved_special_token_35|>': 200048,
#  '<|text_post_train_reserved_special_token_36|>': 200049,
#  '<|text_post_train_reserved_special_token_37|>': 200050,
#  '<|text_post_train_reserved_special_token_38|>': 200051,
#  '<|text_post_train_reserved_special_token_39|>': 200052,
#  '<|text_post_train_reserved_special_token_40|>': 200053,
#  '<|text_post_train_reserved_special_token_41|>': 200054,
#  '<|text_post_train_reserved_special_token_42|>': 200055,
#  '<|text_post_train_reserved_special_token_43|>': 200056,
#  '<|text_post_train_reserved_special_token_44|>': 200057,
#  '<|text_post_train_reserved_special_token_45|>': 200058,
#  '<|text_post_train_reserved_special_token_46|>': 200059,
#  '<|text_post_train_reserved_special_token_47|>': 200060,
#  '<|text_post_train_reserved_special_token_48|>': 200061,
#  '<|text_post_train_reserved_special_token_49|>': 200062,
#  '<|text_post_train_reserved_special_token_50|>': 200063,
#  '<|text_post_train_reserved_special_token_51|>': 200064,
#  '<|text_post_train_reserved_special_token_52|>': 200065,
#  '<|text_post_train_reserved_special_token_53|>': 200066,
#  '<|text_post_train_reserved_special_token_54|>': 200067,
#  '<|text_post_train_reserved_special_token_55|>': 200068,
#  '<|text_post_train_reserved_special_token_56|>': 200069,
#  '<|text_post_train_reserved_special_token_57|>': 200070,
#  '<|text_post_train_reserved_special_token_58|>': 200071,
#  '<|text_post_train_reserved_special_token_59|>': 200072,
#  '<|text_post_train_reserved_special_token_60|>': 200073,
#  '<|text_post_train_reserved_special_token_61|>': 200074,
#  '<|text_post_train_reserved_special_token_62|>': 200075,
#  '<|text_post_train_reserved_special_token_63|>': 200076,
#  '<|text_post_train_reserved_special_token_64|>': 200077,
#  '<|text_post_train_reserved_special_token_65|>': 200078,
#  '<|text_post_train_reserved_special_token_66|>': 200079,
#  '<|image_start|>': 200080,
#  '<|image_end|>': 200081,
#  '<|vision_reserved_special_token_0|>': 200082,
#  '<|vision_reserved_special_token_1|>': 200083,
#  '<|tile_x_separator|>': 200084,
#  '<|tile_y_separator|>': 200085,
#  '<|vision_reserved_special_token_2|>': 200086,
#  '<|vision_reserved_special_token_3|>': 200087,
#  '<|vision_reserved_special_token_4|>': 200088,
#  '<|vision_reserved_special_token_5|>': 200089,
#  '<|image|>': 200090,
#  '<|vision_reserved_special_token_6|>': 200091,
#  '<|patch|>': 200092,
#  '<|vision_reserved_special_token_7|>': 200093,
#  '<|vision_reserved_special_token_8|>': 200094,
#  '<|vision_reserved_special_token_9|>': 200095,
#  '<|vision_reserved_special_token_10|>': 200096,
#  '<|vision_reserved_special_token_11|>': 200097,
#  '<|vision_reserved_special_token_12|>': 200098,
#  '<|vision_reserved_special_token_13|>': 200099,
#  '<|vision_reserved_special_token_14|>': 200100,
#  '<|vision_reserved_special_token_15|>': 200101,
#  '<|vision_reserved_special_token_16|>': 200102,
#  '<|vision_reserved_special_token_17|>': 200103,
#  '<|vision_reserved_special_token_18|>': 200104,
#  '<|vision_reserved_special_token_19|>': 200105,
#  '<|vision_reserved_special_token_20|>': 200106,
#  '<|vision_reserved_special_token_21|>': 200107,
#  '<|vision_reserved_special_token_22|>': 200108,
#  '<|vision_reserved_special_token_23|>': 200109,
#  '<|vision_reserved_special_token_24|>': 200110,
#  '<|vision_reserved_special_token_25|>': 200111,
#  '<|vision_reserved_special_token_26|>': 200112,
#  '<|vision_reserved_special_token_27|>': 200113,
#  '<|vision_reserved_special_token_28|>': 200114,
#  '<|vision_reserved_special_token_29|>': 200115,
#  '<|vision_reserved_special_token_30|>': 200116,
#  '<|vision_reserved_special_token_31|>': 200117,
#  '<|vision_reserved_special_token_32|>': 200118,
#  '<|vision_reserved_special_token_33|>': 200119,
#  '<|vision_reserved_special_token_34|>': 200120,
#  '<|vision_reserved_special_token_35|>': 200121,
#  '<|vision_reserved_special_token_36|>': 200122,
#  '<|vision_reserved_special_token_37|>': 200123,
#  '<|vision_reserved_special_token_38|>': 200124,
#  '<|vision_reserved_special_token_39|>': 200125,
#  '<|vision_reserved_special_token_40|>': 200126,
#  '<|vision_reserved_special_token_41|>': 200127,
#  '<|vision_reserved_special_token_42|>': 200128,
#  '<|vision_reserved_special_token_43|>': 200129,
#  '<|vision_reserved_special_token_44|>': 200130,
#  '<|vision_reserved_special_token_45|>': 200131,
#  '<|vision_reserved_special_token_46|>': 200132,
#  '<|vision_reserved_special_token_47|>': 200133,
#  '<|vision_reserved_special_token_48|>': 200134,
#  '<|vision_reserved_special_token_49|>': 200135,
#  '<|vision_reserved_special_token_50|>': 200136,
#  '<|vision_reserved_special_token_51|>': 200137,
#  '<|vision_reserved_special_token_52|>': 200138,
#  '<|vision_reserved_special_token_53|>': 200139,
#  '<|vision_reserved_special_token_54|>': 200140,
#  '<|vision_reserved_special_token_55|>': 200141,
#  '<|vision_reserved_special_token_56|>': 200142,
#  '<|vision_reserved_special_token_57|>': 200143,
#  '<|vision_reserved_special_token_58|>': 200144,
#  '<|vision_reserved_special_token_59|>': 200145,
#  '<|vision_reserved_special_token_60|>': 200146,
#  '<|vision_reserved_special_token_61|>': 200147,
#  '<|vision_reserved_special_token_62|>': 200148,
#  '<|vision_reserved_special_token_63|>': 200149,
#  '<|vision_reserved_special_token_64|>': 200150,
#  '<|vision_reserved_special_token_65|>': 200151,
#  '<|vision_reserved_special_token_66|>': 200152,
#  '<|vision_reserved_special_token_67|>': 200153,
#  '<|vision_reserved_special_token_68|>': 200154,
#  '<|vision_reserved_special_token_69|>': 200155,
#  '<|vision_reserved_special_token_70|>': 200156,
#  '<|vision_reserved_special_token_71|>': 200157,
#  '<|vision_reserved_special_token_72|>': 200158,
#  '<|vision_reserved_special_token_73|>': 200159,
#  '<|vision_reserved_special_token_74|>': 200160,
#  '<|vision_reserved_special_token_75|>': 200161,
#  '<|vision_reserved_special_token_76|>': 200162,
#  '<|vision_reserved_special_token_77|>': 200163,
#  '<|vision_reserved_special_token_78|>': 200164,
#  '<|vision_reserved_special_token_79|>': 200165,
#  '<|vision_reserved_special_token_80|>': 200166,
#  '<|vision_reserved_special_token_81|>': 200167,
#  '<|vision_reserved_special_token_82|>': 200168,
#  '<|vision_reserved_special_token_83|>': 200169,
#  '<|vision_reserved_special_token_84|>': 200170,
#  '<|vision_reserved_special_token_85|>': 200171,
#  '<|vision_reserved_special_token_86|>': 200172,
#  '<|vision_reserved_special_token_87|>': 200173,
#  '<|vision_reserved_special_token_88|>': 200174,
#  '<|vision_reserved_special_token_89|>': 200175,
#  '<|vision_reserved_special_token_90|>': 200176,
#  '<|vision_reserved_special_token_91|>': 200177,
#  '<|vision_reserved_special_token_92|>': 200178,
#  '<|vision_reserved_special_token_93|>': 200179,
#  '<|vision_reserved_special_token_94|>': 200180,
#  '<|vision_reserved_special_token_95|>': 200181,
#  '<|vision_reserved_special_token_96|>': 200182,
#  '<|vision_reserved_special_token_97|>': 200183,
#  '<|vision_reserved_special_token_98|>': 200184,
#  '<|vision_reserved_special_token_99|>': 200185,
#  '<|vision_reserved_special_token_100|>': 200186,
#  '<|vision_reserved_special_token_101|>': 200187,
#  '<|vision_reserved_special_token_102|>': 200188,
#  '<|vision_reserved_special_token_103|>': 200189,
#  '<|vision_reserved_special_token_104|>': 200190,
#  '<|vision_reserved_special_token_105|>': 200191,
#  '<|vision_reserved_special_token_106|>': 200192,
#  '<|vision_reserved_special_token_107|>': 200193,
#  '<|vision_reserved_special_token_108|>': 200194,
#  '<|vision_reserved_special_token_109|>': 200195,
#  '<|vision_reserved_special_token_110|>': 200196,
#  '<|vision_reserved_special_token_111|>': 200197,
#  '<|vision_reserved_special_token_112|>': 200198,
#  '<|vision_reserved_special_token_113|>': 200199,
#  '<|vision_reserved_special_token_114|>': 200200,
#  '<|vision_reserved_special_token_115|>': 200201,
#  '<|vision_reserved_special_token_116|>': 200202,
#  '<|vision_reserved_special_token_117|>': 200203,
#  '<|vision_reserved_special_token_118|>': 200204,
#  '<|vision_reserved_special_token_119|>': 200205,
#  '<|vision_reserved_special_token_120|>': 200206,
#  '<|vision_reserved_special_token_121|>': 200207,
#  '<|vision_reserved_special_token_122|>': 200208,
#  '<|vision_reserved_special_token_123|>': 200209,
#  '<|vision_reserved_special_token_124|>': 200210,
#  '<|vision_reserved_special_token_125|>': 200211,
#  '<|vision_reserved_special_token_126|>': 200212,
#  '<|vision_reserved_special_token_127|>': 200213,
#  '<|vision_reserved_special_token_128|>': 200214,
#  '<|vision_reserved_special_token_129|>': 200215,
#  '<|vision_reserved_special_token_130|>': 200216,
#  '<|vision_reserved_special_token_131|>': 200217,
#  '<|vision_reserved_special_token_132|>': 200218,
#  '<|vision_reserved_special_token_133|>': 200219,
#  '<|vision_reserved_special_token_134|>': 200220,
#  '<|vision_reserved_special_token_135|>': 200221,
#  '<|vision_reserved_special_token_136|>': 200222,
#  '<|vision_reserved_special_token_137|>': 200223,
#  '<|vision_reserved_special_token_138|>': 200224,
#  '<|vision_reserved_special_token_139|>': 200225,
#  '<|vision_reserved_special_token_140|>': 200226,
#  '<|vision_reserved_special_token_141|>': 200227,
#  '<|vision_reserved_special_token_142|>': 200228,
#  '<|vision_reserved_special_token_143|>': 200229,
#  '<|vision_reserved_special_token_144|>': 200230,
#  '<|vision_reserved_special_token_145|>': 200231,
#  '<|vision_reserved_special_token_146|>': 200232,
#  '<|vision_reserved_special_token_147|>': 200233,
#  '<|vision_reserved_special_token_148|>': 200234,
#  '<|vision_reserved_special_token_149|>': 200235,
#  '<|vision_reserved_special_token_150|>': 200236,
#  '<|vision_reserved_special_token_151|>': 200237,
#  '<|vision_reserved_special_token_152|>': 200238,
#  '<|vision_reserved_special_token_153|>': 200239,
#  '<|vision_reserved_special_token_154|>': 200240,
#  '<|vision_reserved_special_token_155|>': 200241,
#  '<|vision_reserved_special_token_156|>': 200242,
#  '<|vision_reserved_special_token_157|>': 200243,
#  '<|vision_reserved_special_token_158|>': 200244,
#  '<|vision_reserved_special_token_159|>': 200245,
#  '<|vision_reserved_special_token_160|>': 200246,
#  '<|vision_reserved_special_token_161|>': 200247,
#  '<|vision_reserved_special_token_162|>': 200248,
#  '<|vision_reserved_special_token_163|>': 200249,
#  '<|vision_reserved_special_token_164|>': 200250,
#  '<|vision_reserved_special_token_165|>': 200251,
#  '<|vision_reserved_special_token_166|>': 200252,
#  '<|vision_reserved_special_token_167|>': 200253,
#  '<|vision_reserved_special_token_168|>': 200254,
#  '<|vision_reserved_special_token_169|>': 200255,
#  '<|vision_reserved_special_token_170|>': 200256,
#  '<|vision_reserved_special_token_171|>': 200257,
#  '<|vision_reserved_special_token_172|>': 200258,
#  '<|vision_reserved_special_token_173|>': 200259,
#  '<|vision_reserved_special_token_174|>': 200260,
#  '<|vision_reserved_special_token_175|>': 200261,
#  '<|vision_reserved_special_token_176|>': 200262,
#  '<|vision_reserved_special_token_177|>': 200263,
#  '<|vision_reserved_special_token_178|>': 200264,
#  '<|vision_reserved_special_token_179|>': 200265,
#  '<|vision_reserved_special_token_180|>': 200266,
#  '<|vision_reserved_special_token_181|>': 200267,
#  '<|vision_reserved_special_token_182|>': 200268,
#  '<|vision_reserved_special_token_183|>': 200269,
#  '<|vision_reserved_special_token_184|>': 200270,
#  '<|vision_reserved_special_token_185|>': 200271,
#  '<|vision_reserved_special_token_186|>': 200272,
#  '<|vision_reserved_special_token_187|>': 200273,
#  '<|vision_reserved_special_token_188|>': 200274,
#  '<|vision_reserved_special_token_189|>': 200275,
#  '<|vision_reserved_special_token_190|>': 200276,
#  '<|vision_reserved_special_token_191|>': 200277,
#  '<|vision_reserved_special_token_192|>': 200278,
#  '<|vision_reserved_special_token_193|>': 200279,
#  '<|vision_reserved_special_token_194|>': 200280,
#  '<|vision_reserved_special_token_195|>': 200281,
#  '<|vision_reserved_special_token_196|>': 200282,
#  '<|vision_reserved_special_token_197|>': 200283,
#  '<|vision_reserved_special_token_198|>': 200284,
#  '<|vision_reserved_special_token_199|>': 200285,
#  '<|vision_reserved_special_token_200|>': 200286,
#  '<|vision_reserved_special_token_201|>': 200287,
#  '<|vision_reserved_special_token_202|>': 200288,
#  '<|vision_reserved_special_token_203|>': 200289,
#  '<|vision_reserved_special_token_204|>': 200290,
#  '<|vision_reserved_special_token_205|>': 200291,
#  '<|vision_reserved_special_token_206|>': 200292,
#  '<|vision_reserved_special_token_207|>': 200293,
#  '<|vision_reserved_special_token_208|>': 200294,
#  '<|vision_reserved_special_token_209|>': 200295,
#  '<|vision_reserved_special_token_210|>': 200296,
#  '<|vision_reserved_special_token_211|>': 200297,
#  '<|vision_reserved_special_token_212|>': 200298,
#  '<|vision_reserved_special_token_213|>': 200299,
#  '<|vision_reserved_special_token_214|>': 200300,
#  '<|vision_reserved_special_token_215|>': 200301,
#  '<|vision_reserved_special_token_216|>': 200302,
#  '<|vision_reserved_special_token_217|>': 200303,
#  '<|vision_reserved_special_token_218|>': 200304,
#  '<|vision_reserved_special_token_219|>': 200305,
#  '<|vision_reserved_special_token_220|>': 200306,
#  '<|vision_reserved_special_token_221|>': 200307,
#  '<|vision_reserved_special_token_222|>': 200308,
#  '<|vision_reserved_special_token_223|>': 200309,
#  '<|vision_reserved_special_token_224|>': 200310,
#  '<|vision_reserved_special_token_225|>': 200311,
#  '<|vision_reserved_special_token_226|>': 200312,
#  '<|vision_reserved_special_token_227|>': 200313,
#  '<|vision_reserved_special_token_228|>': 200314,
#  '<|vision_reserved_special_token_229|>': 200315,
#  '<|vision_reserved_special_token_230|>': 200316,
#  '<|vision_reserved_special_token_231|>': 200317,
#  '<|vision_reserved_special_token_232|>': 200318,
#  '<|vision_reserved_special_token_233|>': 200319,
#  '<|vision_reserved_special_token_234|>': 200320,
#  '<|vision_reserved_special_token_235|>': 200321,
#  '<|vision_reserved_special_token_236|>': 200322,
#  '<|vision_reserved_special_token_237|>': 200323,
#  '<|vision_reserved_special_token_238|>': 200324,
#  '<|vision_reserved_special_token_239|>': 200325,
#  '<|vision_reserved_special_token_240|>': 200326,
#  '<|vision_reserved_special_token_241|>': 200327,
#  '<|vision_reserved_special_token_242|>': 200328,
#  '<|vision_reserved_special_token_243|>': 200329,
#  '<|vision_reserved_special_token_244|>': 200330,
#  '<|vision_reserved_special_token_245|>': 200331,
#  '<|vision_reserved_special_token_246|>': 200332,
#  '<|vision_reserved_special_token_247|>': 200333,
#  '<|vision_reserved_special_token_248|>': 200334,
#  '<|vision_reserved_special_token_249|>': 200335,
#  '<|vision_reserved_special_token_250|>': 200336,
#  '<|vision_reserved_special_token_251|>': 200337,
#  '<|vision_reserved_special_token_252|>': 200338,
#  '<|vision_reserved_special_token_253|>': 200339,
#  '<|vision_reserved_special_token_254|>': 200340,
#  '<|vision_reserved_special_token_255|>': 200341,
#  '<|vision_reserved_special_token_256|>': 200342,
#  '<|vision_reserved_special_token_257|>': 200343,
#  '<|vision_reserved_special_token_258|>': 200344,
#  '<|vision_reserved_special_token_259|>': 200345,
#  '<|vision_reserved_special_token_260|>': 200346,
#  '<|vision_reserved_special_token_261|>': 200347,
#  '<|vision_reserved_special_token_262|>': 200348,
#  '<|vision_reserved_special_token_263|>': 200349,
#  '<|vision_reserved_special_token_264|>': 200350,
#  '<|vision_reserved_special_token_265|>': 200351,
#  '<|vision_reserved_special_token_266|>': 200352,
#  '<|vision_reserved_special_token_267|>': 200353,
#  '<|vision_reserved_special_token_268|>': 200354,
#  '<|vision_reserved_special_token_269|>': 200355,
#  '<|vision_reserved_special_token_270|>': 200356,
#  '<|vision_reserved_special_token_271|>': 200357,
#  '<|vision_reserved_special_token_272|>': 200358,
#  '<|vision_reserved_special_token_273|>': 200359,
#  '<|vision_reserved_special_token_274|>': 200360,
#  '<|vision_reserved_special_token_275|>': 200361,
#  '<|vision_reserved_special_token_276|>': 200362,
#  '<|vision_reserved_special_token_277|>': 200363,
#  '<|vision_reserved_special_token_278|>': 200364,
#  '<|vision_reserved_special_token_279|>': 200365,
#  '<|vision_reserved_special_token_280|>': 200366,
#  '<|vision_reserved_special_token_281|>': 200367,
#  '<|vision_reserved_special_token_282|>': 200368,
#  '<|vision_reserved_special_token_283|>': 200369,
#  '<|vision_reserved_special_token_284|>': 200370,
#  '<|vision_reserved_special_token_285|>': 200371,
#  '<|vision_reserved_special_token_286|>': 200372,
#  '<|vision_reserved_special_token_287|>': 200373,
#  '<|vision_reserved_special_token_288|>': 200374,
#  '<|vision_reserved_special_token_289|>': 200375,
#  '<|vision_reserved_special_token_290|>': 200376,
#  '<|vision_reserved_special_token_291|>': 200377,
#  '<|vision_reserved_special_token_292|>': 200378,
#  '<|vision_reserved_special_token_293|>': 200379,
#  '<|vision_reserved_special_token_294|>': 200380,
#  '<|vision_reserved_special_token_295|>': 200381,
#  '<|vision_reserved_special_token_296|>': 200382,
#  '<|vision_reserved_special_token_297|>': 200383,
#  '<|vision_reserved_special_token_298|>': 200384,
#  '<|vision_reserved_special_token_299|>': 200385,
#  '<|vision_reserved_special_token_300|>': 200386,
#  '<|vision_reserved_special_token_301|>': 200387,
#  '<|vision_reserved_special_token_302|>': 200388,
#  '<|vision_reserved_special_token_303|>': 200389,
#  '<|vision_reserved_special_token_304|>': 200390,
#  '<|vision_reserved_special_token_305|>': 200391,
#  '<|vision_reserved_special_token_306|>': 200392,
#  '<|vision_reserved_special_token_307|>': 200393,
#  '<|vision_reserved_special_token_308|>': 200394,
#  '<|vision_reserved_special_token_309|>': 200395,
#  '<|vision_reserved_special_token_310|>': 200396,
#  '<|vision_reserved_special_token_311|>': 200397,
#  '<|vision_reserved_special_token_312|>': 200398,
#  '<|vision_reserved_special_token_313|>': 200399,
#  '<|vision_reserved_special_token_314|>': 200400,
#  '<|vision_reserved_special_token_315|>': 200401,
#  '<|vision_reserved_special_token_316|>': 200402,
#  '<|vision_reserved_special_token_317|>': 200403,
#  '<|vision_reserved_special_token_318|>': 200404,
#  '<|vision_reserved_special_token_319|>': 200405,
#  '<|vision_reserved_special_token_320|>': 200406,
#  '<|vision_reserved_special_token_321|>': 200407,
#  '<|vision_reserved_special_token_322|>': 200408,
#  '<|vision_reserved_special_token_323|>': 200409,
#  '<|vision_reserved_special_token_324|>': 200410,
#  '<|vision_reserved_special_token_325|>': 200411,
#  '<|vision_reserved_special_token_326|>': 200412,
#  '<|vision_reserved_special_token_327|>': 200413,
#  '<|vision_reserved_special_token_328|>': 200414,
#  '<|vision_reserved_special_token_329|>': 200415,
#  '<|vision_reserved_special_token_330|>': 200416,
#  '<|vision_reserved_special_token_331|>': 200417,
#  '<|vision_reserved_special_token_332|>': 200418,
#  '<|vision_reserved_special_token_333|>': 200419,
#  '<|vision_reserved_special_token_334|>': 200420,
#  '<|vision_reserved_special_token_335|>': 200421,
#  '<|vision_reserved_special_token_336|>': 200422,
#  '<|vision_reserved_special_token_337|>': 200423,
#  '<|vision_reserved_special_token_338|>': 200424,
#  '<|vision_reserved_special_token_339|>': 200425,
#  '<|vision_reserved_special_token_340|>': 200426,
#  '<|vision_reserved_special_token_341|>': 200427,
#  '<|vision_reserved_special_token_342|>': 200428,
#  '<|vision_reserved_special_token_343|>': 200429,
#  '<|vision_reserved_special_token_344|>': 200430,
#  '<|vision_reserved_special_token_345|>': 200431,
#  '<|vision_reserved_special_token_346|>': 200432,
#  '<|vision_reserved_special_token_347|>': 200433,
#  '<|vision_reserved_special_token_348|>': 200434,
#  '<|vision_reserved_special_token_349|>': 200435,
#  '<|vision_reserved_special_token_350|>': 200436,
#  '<|vision_reserved_special_token_351|>': 200437,
#  '<|vision_reserved_special_token_352|>': 200438,
#  '<|vision_reserved_special_token_353|>': 200439,
#  '<|vision_reserved_special_token_354|>': 200440,
#  '<|vision_reserved_special_token_355|>': 200441,
#  '<|vision_reserved_special_token_356|>': 200442,
#  '<|vision_reserved_special_token_357|>': 200443,
#  '<|vision_reserved_special_token_358|>': 200444,
#  '<|vision_reserved_special_token_359|>': 200445,
#  '<|vision_reserved_special_token_360|>': 200446,
#  '<|vision_reserved_special_token_361|>': 200447,
#  '<|vision_reserved_special_token_362|>': 200448,
#  '<|vision_reserved_special_token_363|>': 200449,
#  '<|vision_reserved_special_token_364|>': 200450,
#  '<|vision_reserved_special_token_365|>': 200451,
#  '<|vision_reserved_special_token_366|>': 200452,
#  '<|vision_reserved_special_token_367|>': 200453,
#  '<|vision_reserved_special_token_368|>': 200454,
#  '<|vision_reserved_special_token_369|>': 200455,
#  '<|vision_reserved_special_token_370|>': 200456,
#  '<|vision_reserved_special_token_371|>': 200457,
#  '<|vision_reserved_special_token_372|>': 200458,
#  '<|vision_reserved_special_token_373|>': 200459,
#  '<|vision_reserved_special_token_374|>': 200460,
#  '<|vision_reserved_special_token_375|>': 200461,
#  '<|vision_reserved_special_token_376|>': 200462,
#  '<|vision_reserved_special_token_377|>': 200463,
#  '<|vision_reserved_special_token_378|>': 200464,
#  '<|vision_reserved_special_token_379|>': 200465,
#  '<|vision_reserved_special_token_380|>': 200466,
#  '<|vision_reserved_special_token_381|>': 200467,
#  '<|vision_reserved_special_token_382|>': 200468,
#  '<|vision_reserved_special_token_383|>': 200469,
#  '<|vision_reserved_special_token_384|>': 200470,
#  '<|vision_reserved_special_token_385|>': 200471,
#  '<|vision_reserved_special_token_386|>': 200472,
#  '<|vision_reserved_special_token_387|>': 200473,
#  '<|vision_reserved_special_token_388|>': 200474,
#  '<|vision_reserved_special_token_389|>': 200475,
#  '<|vision_reserved_special_token_390|>': 200476,
#  '<|vision_reserved_special_token_391|>': 200477,
#  '<|vision_reserved_special_token_392|>': 200478,
#  '<|vision_reserved_special_token_393|>': 200479,
#  '<|vision_reserved_special_token_394|>': 200480,
#  '<|vision_reserved_special_token_395|>': 200481,
#  '<|vision_reserved_special_token_396|>': 200482,
#  '<|vision_reserved_special_token_397|>': 200483,
#  '<|vision_reserved_special_token_398|>': 200484,
#  '<|vision_reserved_special_token_399|>': 200485,
#  '<|vision_reserved_special_token_400|>': 200486,
#  '<|vision_reserved_special_token_401|>': 200487,
#  '<|vision_reserved_special_token_402|>': 200488,
#  '<|vision_reserved_special_token_403|>': 200489,
#  '<|vision_reserved_special_token_404|>': 200490,
#  '<|vision_reserved_special_token_405|>': 200491,
#  '<|vision_reserved_special_token_406|>': 200492,
#  '<|vision_reserved_special_token_407|>': 200493,
#  '<|vision_reserved_special_token_408|>': 200494,
#  '<|vision_reserved_special_token_409|>': 200495,
#  '<|vision_reserved_special_token_410|>': 200496,
#  '<|vision_reserved_special_token_411|>': 200497,
#  '<|vision_reserved_special_token_412|>': 200498,
#  '<|vision_reserved_special_token_413|>': 200499,
#  '<|vision_reserved_special_token_414|>': 200500,
#  '<|vision_reserved_special_token_415|>': 200501,
#  '<|vision_reserved_special_token_416|>': 200502,
#  '<|vision_reserved_special_token_417|>': 200503,
#  '<|vision_reserved_special_token_418|>': 200504,
#  '<|vision_reserved_special_token_419|>': 200505,
#  '<|vision_reserved_special_token_420|>': 200506,
#  '<|vision_reserved_special_token_421|>': 200507,
#  '<|vision_reserved_special_token_422|>': 200508,
#  '<|vision_reserved_special_token_423|>': 200509,
#  '<|vision_reserved_special_token_424|>': 200510,
#  '<|vision_reserved_special_token_425|>': 200511,
#  '<|vision_reserved_special_token_426|>': 200512,
#  '<|vision_reserved_special_token_427|>': 200513,
#  '<|vision_reserved_special_token_428|>': 200514,
#  '<|vision_reserved_special_token_429|>': 200515,
#  '<|vision_reserved_special_token_430|>': 200516,
#  '<|vision_reserved_special_token_431|>': 200517,
#  '<|vision_reserved_special_token_432|>': 200518,
#  '<|vision_reserved_special_token_433|>': 200519,
#  '<|vision_reserved_special_token_434|>': 200520,
#  '<|vision_reserved_special_token_435|>': 200521,
#  '<|vision_reserved_special_token_436|>': 200522,
#  '<|vision_reserved_special_token_437|>': 200523,
#  '<|vision_reserved_special_token_438|>': 200524,
#  '<|vision_reserved_special_token_439|>': 200525,
#  '<|vision_reserved_special_token_440|>': 200526,
#  '<|vision_reserved_special_token_441|>': 200527,
#  '<|vision_reserved_special_token_442|>': 200528,
#  '<|vision_reserved_special_token_443|>': 200529,
#  '<|vision_reserved_special_token_444|>': 200530,
#  '<|vision_reserved_special_token_445|>': 200531,
#  '<|vision_reserved_special_token_446|>': 200532,
#  '<|vision_reserved_special_token_447|>': 200533,
#  '<|vision_reserved_special_token_448|>': 200534,
#  '<|vision_reserved_special_token_449|>': 200535,
#  '<|vision_reserved_special_token_450|>': 200536,
#  '<|vision_reserved_special_token_451|>': 200537,
#  '<|vision_reserved_special_token_452|>': 200538,
#  '<|vision_reserved_special_token_453|>': 200539,
#  '<|vision_reserved_special_token_454|>': 200540,
#  '<|vision_reserved_special_token_455|>': 200541,
#  '<|vision_reserved_special_token_456|>': 200542,
#  '<|vision_reserved_special_token_457|>': 200543,
#  '<|vision_reserved_special_token_458|>': 200544,
#  '<|vision_reserved_special_token_459|>': 200545,
#  '<|vision_reserved_special_token_460|>': 200546,
#  '<|vision_reserved_special_token_461|>': 200547,
#  '<|vision_reserved_special_token_462|>': 200548,
#  '<|vision_reserved_special_token_463|>': 200549,
#  '<|vision_reserved_special_token_464|>': 200550,
#  '<|vision_reserved_special_token_465|>': 200551,
#  '<|vision_reserved_special_token_466|>': 200552,
#  '<|vision_reserved_special_token_467|>': 200553,
#  '<|vision_reserved_special_token_468|>': 200554,
#  '<|vision_reserved_special_token_469|>': 200555,
#  '<|vision_reserved_special_token_470|>': 200556,
#  '<|vision_reserved_special_token_471|>': 200557,
#  '<|vision_reserved_special_token_472|>': 200558,
#  '<|vision_reserved_special_token_473|>': 200559,
#  '<|vision_reserved_special_token_474|>': 200560,
#  '<|vision_reserved_special_token_475|>': 200561,
#  '<|vision_reserved_special_token_476|>': 200562,
#  '<|vision_reserved_special_token_477|>': 200563,
#  '<|vision_reserved_special_token_478|>': 200564,
#  '<|vision_reserved_special_token_479|>': 200565,
#  '<|vision_reserved_special_token_480|>': 200566,
#  '<|vision_reserved_special_token_481|>': 200567,
#  '<|vision_reserved_special_token_482|>': 200568,
#  '<|vision_reserved_special_token_483|>': 200569,
#  '<|vision_reserved_special_token_484|>': 200570,
#  '<|vision_reserved_special_token_485|>': 200571,
#  '<|vision_reserved_special_token_486|>': 200572,
#  '<|vision_reserved_special_token_487|>': 200573,
#  '<|vision_reserved_special_token_488|>': 200574,
#  '<|vision_reserved_special_token_489|>': 200575,
#  '<|vision_reserved_special_token_490|>': 200576,
#  '<|vision_reserved_special_token_491|>': 200577,
#  '<|vision_reserved_special_token_492|>': 200578,
#  '<|vision_reserved_special_token_493|>': 200579,
#  '<|vision_reserved_special_token_494|>': 200580,
#  '<|vision_reserved_special_token_495|>': 200581,
#  '<|vision_reserved_special_token_496|>': 200582,
#  '<|vision_reserved_special_token_497|>': 200583,
#  '<|vision_reserved_special_token_498|>': 200584,
#  '<|vision_reserved_special_token_499|>': 200585,
#  '<|vision_reserved_special_token_500|>': 200586,
#  '<|vision_reserved_special_token_501|>': 200587,
#  '<|vision_reserved_special_token_502|>': 200588,
#  '<|vision_reserved_special_token_503|>': 200589,
#  '<|vision_reserved_special_token_504|>': 200590,
#  '<|vision_reserved_special_token_505|>': 200591,
#  '<|vision_reserved_special_token_506|>': 200592,
#  '<|vision_reserved_special_token_507|>': 200593,
#  '<|vision_reserved_special_token_508|>': 200594,
#  '<|vision_reserved_special_token_509|>': 200595,
#  '<|vision_reserved_special_token_510|>': 200596,
#  '<|vision_reserved_special_token_511|>': 200597,
#  '<|vision_reserved_special_token_512|>': 200598,
#  '<|vision_reserved_special_token_513|>': 200599,
#  '<|vision_reserved_special_token_514|>': 200600,
#  '<|vision_reserved_special_token_515|>': 200601,
#  '<|vision_reserved_special_token_516|>': 200602,
#  '<|vision_reserved_special_token_517|>': 200603,
#  '<|vision_reserved_special_token_518|>': 200604,
#  '<|vision_reserved_special_token_519|>': 200605,
#  '<|vision_reserved_special_token_520|>': 200606,
#  '<|vision_reserved_special_token_521|>': 200607,
#  '<|vision_reserved_special_token_522|>': 200608,
#  '<|vision_reserved_special_token_523|>': 200609,
#  '<|vision_reserved_special_token_524|>': 200610,
#  '<|vision_reserved_special_token_525|>': 200611,
#  '<|vision_reserved_special_token_526|>': 200612,
#  '<|vision_reserved_special_token_527|>': 200613,
#  '<|vision_reserved_special_token_528|>': 200614,
#  '<|vision_reserved_special_token_529|>': 200615,
#  '<|vision_reserved_special_token_530|>': 200616,
#  '<|vision_reserved_special_token_531|>': 200617,
#  '<|vision_reserved_special_token_532|>': 200618,
#  '<|vision_reserved_special_token_533|>': 200619,
#  '<|vision_reserved_special_token_534|>': 200620,
#  '<|vision_reserved_special_token_535|>': 200621,
#  '<|vision_reserved_special_token_536|>': 200622,
#  '<|vision_reserved_special_token_537|>': 200623,
#  '<|vision_reserved_special_token_538|>': 200624,
#  '<|vision_reserved_special_token_539|>': 200625,
#  '<|vision_reserved_special_token_540|>': 200626,
#  '<|vision_reserved_special_token_541|>': 200627,
#  '<|vision_reserved_special_token_542|>': 200628,
#  '<|vision_reserved_special_token_543|>': 200629,
#  '<|vision_reserved_special_token_544|>': 200630,
#  '<|vision_reserved_special_token_545|>': 200631,
#  '<|vision_reserved_special_token_546|>': 200632,
#  '<|vision_reserved_special_token_547|>': 200633,
#  '<|vision_reserved_special_token_548|>': 200634,
#  '<|vision_reserved_special_token_549|>': 200635,
#  '<|vision_reserved_special_token_550|>': 200636,
#  '<|vision_reserved_special_token_551|>': 200637,
#  '<|vision_reserved_special_token_552|>': 200638,
#  '<|vision_reserved_special_token_553|>': 200639,
#  '<|vision_reserved_special_token_554|>': 200640,
#  '<|vision_reserved_special_token_555|>': 200641,
#  '<|vision_reserved_special_token_556|>': 200642,
#  '<|vision_reserved_special_token_557|>': 200643,
#  '<|vision_reserved_special_token_558|>': 200644,
#  '<|vision_reserved_special_token_559|>': 200645,
#  '<|vision_reserved_special_token_560|>': 200646,
#  '<|vision_reserved_special_token_561|>': 200647,
#  '<|vision_reserved_special_token_562|>': 200648,
#  '<|vision_reserved_special_token_563|>': 200649,
#  '<|vision_reserved_special_token_564|>': 200650,
#  '<|vision_reserved_special_token_565|>': 200651,
#  '<|vision_reserved_special_token_566|>': 200652,
#  '<|vision_reserved_special_token_567|>': 200653,
#  '<|vision_reserved_special_token_568|>': 200654,
#  '<|vision_reserved_special_token_569|>': 200655,
#  '<|vision_reserved_special_token_570|>': 200656,
#  '<|vision_reserved_special_token_571|>': 200657,
#  '<|vision_reserved_special_token_572|>': 200658,
#  '<|vision_reserved_special_token_573|>': 200659,
#  '<|vision_reserved_special_token_574|>': 200660,
#  '<|vision_reserved_special_token_575|>': 200661,
#  '<|vision_reserved_special_token_576|>': 200662,
#  '<|vision_reserved_special_token_577|>': 200663,
#  '<|vision_reserved_special_token_578|>': 200664,
#  '<|vision_reserved_special_token_579|>': 200665,
#  '<|vision_reserved_special_token_580|>': 200666,
#  '<|vision_reserved_special_token_581|>': 200667,
#  '<|vision_reserved_special_token_582|>': 200668,
#  '<|vision_reserved_special_token_583|>': 200669,
#  '<|vision_reserved_special_token_584|>': 200670,
#  '<|vision_reserved_special_token_585|>': 200671,
#  '<|vision_reserved_special_token_586|>': 200672,
#  '<|vision_reserved_special_token_587|>': 200673,
#  '<|vision_reserved_special_token_588|>': 200674,
#  '<|vision_reserved_special_token_589|>': 200675,
#  '<|vision_reserved_special_token_590|>': 200676,
#  '<|vision_reserved_special_token_591|>': 200677,
#  '<|vision_reserved_special_token_592|>': 200678,
#  '<|vision_reserved_special_token_593|>': 200679,
#  '<|vision_reserved_special_token_594|>': 200680,
#  '<|vision_reserved_special_token_595|>': 200681,
#  '<|vision_reserved_special_token_596|>': 200682,
#  '<|vision_reserved_special_token_597|>': 200683,
#  '<|vision_reserved_special_token_598|>': 200684,
#  '<|vision_reserved_special_token_599|>': 200685,
#  '<|vision_reserved_special_token_600|>': 200686,
#  '<|vision_reserved_special_token_601|>': 200687,
#  '<|vision_reserved_special_token_602|>': 200688,
#  '<|vision_reserved_special_token_603|>': 200689,
#  '<|vision_reserved_special_token_604|>': 200690,
#  '<|vision_reserved_special_token_605|>': 200691,
#  '<|vision_reserved_special_token_606|>': 200692,
#  '<|vision_reserved_special_token_607|>': 200693,
#  '<|vision_reserved_special_token_608|>': 200694,
#  '<|vision_reserved_special_token_609|>': 200695,
#  '<|vision_reserved_special_token_610|>': 200696,
#  '<|vision_reserved_special_token_611|>': 200697,
#  '<|vision_reserved_special_token_612|>': 200698,
#  '<|vision_reserved_special_token_613|>': 200699,
#  '<|vision_reserved_special_token_614|>': 200700,
#  '<|vision_reserved_special_token_615|>': 200701,
#  '<|vision_reserved_special_token_616|>': 200702,
#  '<|vision_reserved_special_token_617|>': 200703,
#  '<|vision_reserved_special_token_618|>': 200704,
#  '<|vision_reserved_special_token_619|>': 200705,
#  '<|vision_reserved_special_token_620|>': 200706,
#  '<|vision_reserved_special_token_621|>': 200707,
#  '<|vision_reserved_special_token_622|>': 200708,
#  '<|vision_reserved_special_token_623|>': 200709,
#  '<|vision_reserved_special_token_624|>': 200710,
#  '<|vision_reserved_special_token_625|>': 200711,
#  '<|vision_reserved_special_token_626|>': 200712,
#  '<|vision_reserved_special_token_627|>': 200713,
#  '<|vision_reserved_special_token_628|>': 200714,
#  '<|vision_reserved_special_token_629|>': 200715,
#  '<|vision_reserved_special_token_630|>': 200716,
#  '<|vision_reserved_special_token_631|>': 200717,
#  '<|vision_reserved_special_token_632|>': 200718,
#  '<|vision_reserved_special_token_633|>': 200719,
#  '<|vision_reserved_special_token_634|>': 200720,
#  '<|vision_reserved_special_token_635|>': 200721,
#  '<|vision_reserved_special_token_636|>': 200722,
#  '<|vision_reserved_special_token_637|>': 200723,
#  '<|vision_reserved_special_token_638|>': 200724,
#  '<|vision_reserved_special_token_639|>': 200725,
#  '<|vision_reserved_special_token_640|>': 200726,
#  '<|vision_reserved_special_token_641|>': 200727,
#  '<|vision_reserved_special_token_642|>': 200728,
#  '<|vision_reserved_special_token_643|>': 200729,
#  '<|vision_reserved_special_token_644|>': 200730,
#  '<|vision_reserved_special_token_645|>': 200731,
#  '<|vision_reserved_special_token_646|>': 200732,
#  '<|vision_reserved_special_token_647|>': 200733,
#  '<|vision_reserved_special_token_648|>': 200734,
#  '<|vision_reserved_special_token_649|>': 200735,
#  '<|vision_reserved_special_token_650|>': 200736,
#  '<|vision_reserved_special_token_651|>': 200737,
#  '<|vision_reserved_special_token_652|>': 200738,
#  '<|vision_reserved_special_token_653|>': 200739,
#  '<|vision_reserved_special_token_654|>': 200740,
#  '<|vision_reserved_special_token_655|>': 200741,
#  '<|vision_reserved_special_token_656|>': 200742,
#  '<|vision_reserved_special_token_657|>': 200743,
#  '<|vision_reserved_special_token_658|>': 200744,
#  '<|vision_reserved_special_token_659|>': 200745,
#  '<|vision_reserved_special_token_660|>': 200746,
#  '<|vision_reserved_special_token_661|>': 200747,
#  '<|vision_reserved_special_token_662|>': 200748,
#  '<|vision_reserved_special_token_663|>': 200749,
#  '<|vision_reserved_special_token_664|>': 200750,
#  '<|vision_reserved_special_token_665|>': 200751,
#  '<|vision_reserved_special_token_666|>': 200752,
#  '<|vision_reserved_special_token_667|>': 200753,
#  '<|vision_reserved_special_token_668|>': 200754,
#  '<|vision_reserved_special_token_669|>': 200755,
#  '<|vision_reserved_special_token_670|>': 200756,
#  '<|vision_reserved_special_token_671|>': 200757,
#  '<|vision_reserved_special_token_672|>': 200758,
#  '<|vision_reserved_special_token_673|>': 200759,
#  '<|vision_reserved_special_token_674|>': 200760,
#  '<|vision_reserved_special_token_675|>': 200761,
#  '<|vision_reserved_special_token_676|>': 200762,
#  '<|vision_reserved_special_token_677|>': 200763,
#  '<|vision_reserved_special_token_678|>': 200764,
#  '<|vision_reserved_special_token_679|>': 200765,
#  '<|vision_reserved_special_token_680|>': 200766,
#  '<|vision_reserved_special_token_681|>': 200767,
#  '<|vision_reserved_special_token_682|>': 200768,
#  '<|vision_reserved_special_token_683|>': 200769,
#  '<|vision_reserved_special_token_684|>': 200770,
#  '<|vision_reserved_special_token_685|>': 200771,
#  '<|vision_reserved_special_token_686|>': 200772,
#  '<|vision_reserved_special_token_687|>': 200773,
#  '<|vision_reserved_special_token_688|>': 200774,
#  '<|vision_reserved_special_token_689|>': 200775,
#  '<|vision_reserved_special_token_690|>': 200776,
#  '<|vision_reserved_special_token_691|>': 200777,
#  '<|vision_reserved_special_token_692|>': 200778,
#  '<|vision_reserved_special_token_693|>': 200779,
#  '<|vision_reserved_special_token_694|>': 200780,
#  '<|vision_reserved_special_token_695|>': 200781,
#  '<|vision_reserved_special_token_696|>': 200782,
#  '<|vision_reserved_special_token_697|>': 200783,
#  '<|vision_reserved_special_token_698|>': 200784,
#  '<|vision_reserved_special_token_699|>': 200785,
#  '<|vision_reserved_special_token_700|>': 200786,
#  '<|vision_reserved_special_token_701|>': 200787,
#  '<|vision_reserved_special_token_702|>': 200788,
#  '<|vision_reserved_special_token_703|>': 200789,
#  '<|vision_reserved_special_token_704|>': 200790,
#  '<|vision_reserved_special_token_705|>': 200791,
#  '<|vision_reserved_special_token_706|>': 200792,
#  '<|vision_reserved_special_token_707|>': 200793,
#  '<|vision_reserved_special_token_708|>': 200794,
#  '<|vision_reserved_special_token_709|>': 200795,
#  '<|vision_reserved_special_token_710|>': 200796,
#  '<|vision_reserved_special_token_711|>': 200797,
#  '<|vision_reserved_special_token_712|>': 200798,
#  '<|vision_reserved_special_token_713|>': 200799,
#  '<|vision_reserved_special_token_714|>': 200800,
#  '<|vision_reserved_special_token_715|>': 200801,
#  '<|vision_reserved_special_token_716|>': 200802,
#  '<|vision_reserved_special_token_717|>': 200803,
#  '<|vision_reserved_special_token_718|>': 200804,
#  '<|vision_reserved_special_token_719|>': 200805,
#  '<|vision_reserved_special_token_720|>': 200806,
#  '<|vision_reserved_special_token_721|>': 200807,
#  '<|vision_reserved_special_token_722|>': 200808,
#  '<|vision_reserved_special_token_723|>': 200809,
#  '<|vision_reserved_special_token_724|>': 200810,
#  '<|vision_reserved_special_token_725|>': 200811,
#  '<|vision_reserved_special_token_726|>': 200812,
#  '<|vision_reserved_special_token_727|>': 200813,
#  '<|vision_reserved_special_token_728|>': 200814,
#  '<|vision_reserved_special_token_729|>': 200815,
#  '<|vision_reserved_special_token_730|>': 200816,
#  '<|vision_reserved_special_token_731|>': 200817,
#  '<|vision_reserved_special_token_732|>': 200818,
#  '<|vision_reserved_special_token_733|>': 200819,
#  '<|vision_reserved_special_token_734|>': 200820,
#  '<|vision_reserved_special_token_735|>': 200821,
#  '<|vision_reserved_special_token_736|>': 200822,
#  '<|vision_reserved_special_token_737|>': 200823,
#  '<|vision_reserved_special_token_738|>': 200824,
#  '<|vision_reserved_special_token_739|>': 200825,
#  '<|vision_reserved_special_token_740|>': 200826,
#  '<|vision_reserved_special_token_741|>': 200827,
#  '<|vision_reserved_special_token_742|>': 200828,
#  '<|vision_reserved_special_token_743|>': 200829,
#  '<|vision_reserved_special_token_744|>': 200830,
#  '<|vision_reserved_special_token_745|>': 200831,
#  '<|vision_reserved_special_token_746|>': 200832,
#  '<|vision_reserved_special_token_747|>': 200833,
#  '<|vision_reserved_special_token_748|>': 200834,
#  '<|vision_reserved_special_token_749|>': 200835,
#  '<|vision_reserved_special_token_750|>': 200836,
#  '<|vision_reserved_special_token_751|>': 200837,
#  '<|vision_reserved_special_token_752|>': 200838,
#  '<|vision_reserved_special_token_753|>': 200839,
#  '<|vision_reserved_special_token_754|>': 200840,
#  '<|vision_reserved_special_token_755|>': 200841,
#  '<|vision_reserved_special_token_756|>': 200842,
#  '<|vision_reserved_special_token_757|>': 200843,
#  '<|vision_reserved_special_token_758|>': 200844,
#  '<|vision_reserved_special_token_759|>': 200845,
#  '<|vision_reserved_special_token_760|>': 200846,
#  '<|vision_reserved_special_token_761|>': 200847,
#  '<|vision_reserved_special_token_762|>': 200848,
#  '<|vision_reserved_special_token_763|>': 200849,
#  '<|vision_reserved_special_token_764|>': 200850,
#  '<|vision_reserved_special_token_765|>': 200851,
#  '<|vision_reserved_special_token_766|>': 200852,
#  '<|vision_reserved_special_token_767|>': 200853,
#  '<|vision_reserved_special_token_768|>': 200854,
#  '<|vision_reserved_special_token_769|>': 200855,
#  '<|vision_reserved_special_token_770|>': 200856,
#  '<|vision_reserved_special_token_771|>': 200857,
#  '<|vision_reserved_special_token_772|>': 200858,
#  '<|vision_reserved_special_token_773|>': 200859,
#  '<|vision_reserved_special_token_774|>': 200860,
#  '<|vision_reserved_special_token_775|>': 200861,
#  '<|vision_reserved_special_token_776|>': 200862,
#  '<|vision_reserved_special_token_777|>': 200863,
#  '<|vision_reserved_special_token_778|>': 200864,
#  '<|vision_reserved_special_token_779|>': 200865,
#  '<|vision_reserved_special_token_780|>': 200866,
#  '<|vision_reserved_special_token_781|>': 200867,
#  '<|vision_reserved_special_token_782|>': 200868,
#  '<|vision_reserved_special_token_783|>': 200869,
#  '<|vision_reserved_special_token_784|>': 200870,
#  '<|vision_reserved_special_token_785|>': 200871,
#  '<|vision_reserved_special_token_786|>': 200872,
#  '<|vision_reserved_special_token_787|>': 200873,
#  '<|vision_reserved_special_token_788|>': 200874,
#  '<|vision_reserved_special_token_789|>': 200875,
#  '<|vision_reserved_special_token_790|>': 200876,
#  '<|vision_reserved_special_token_791|>': 200877,
#  '<|vision_reserved_special_token_792|>': 200878,
#  '<|vision_reserved_special_token_793|>': 200879,
#  '<|vision_reserved_special_token_794|>': 200880,
#  '<|vision_reserved_special_token_795|>': 200881,
#  '<|vision_reserved_special_token_796|>': 200882,
#  '<|vision_reserved_special_token_797|>': 200883,
#  '<|vision_reserved_special_token_798|>': 200884,
#  '<|vision_reserved_special_token_799|>': 200885,
#  '<|vision_reserved_special_token_800|>': 200886,
#  '<|vision_reserved_special_token_801|>': 200887,
#  '<|vision_reserved_special_token_802|>': 200888,
#  '<|vision_reserved_special_token_803|>': 200889,
#  '<|vision_reserved_special_token_804|>': 200890,
#  '<|vision_reserved_special_token_805|>': 200891,
#  '<|vision_reserved_special_token_806|>': 200892,
#  '<|vision_reserved_special_token_807|>': 200893,
#  '<|vision_reserved_special_token_808|>': 200894,
#  '<|vision_reserved_special_token_809|>': 200895,
#  '<|vision_reserved_special_token_810|>': 200896,
#  '<|vision_reserved_special_token_811|>': 200897,
#  '<|vision_reserved_special_token_812|>': 200898,
#  '<|vision_reserved_special_token_813|>': 200899,
#  '<|vision_reserved_special_token_814|>': 200900,
#  '<|vision_reserved_special_token_815|>': 200901,
#  '<|vision_reserved_special_token_816|>': 200902,
#  '<|vision_reserved_special_token_817|>': 200903,
#  '<|vision_reserved_special_token_818|>': 200904,
#  '<|vision_reserved_special_token_819|>': 200905,
#  '<|vision_reserved_special_token_820|>': 200906,
#  '<|vision_reserved_special_token_821|>': 200907,
#  '<|vision_reserved_special_token_822|>': 200908,
#  '<|vision_reserved_special_token_823|>': 200909,
#  '<|vision_reserved_special_token_824|>': 200910,
#  '<|vision_reserved_special_token_825|>': 200911,
#  '<|vision_reserved_special_token_826|>': 200912,
#  '<|vision_reserved_special_token_827|>': 200913,
#  '<|vision_reserved_special_token_828|>': 200914,
#  '<|vision_reserved_special_token_829|>': 200915,
#  '<|vision_reserved_special_token_830|>': 200916,
#  '<|vision_reserved_special_token_831|>': 200917,
#  '<|vision_reserved_special_token_832|>': 200918,
#  '<|vision_reserved_special_token_833|>': 200919,
#  '<|vision_reserved_special_token_834|>': 200920,
#  '<|vision_reserved_special_token_835|>': 200921,
#  '<|vision_reserved_special_token_836|>': 200922,
#  '<|vision_reserved_special_token_837|>': 200923,
#  '<|vision_reserved_special_token_838|>': 200924,
#  '<|vision_reserved_special_token_839|>': 200925,
#  '<|vision_reserved_special_token_840|>': 200926,
#  '<|vision_reserved_special_token_841|>': 200927,
#  '<|vision_reserved_special_token_842|>': 200928,
#  '<|vision_reserved_special_token_843|>': 200929,
#  '<|vision_reserved_special_token_844|>': 200930,
#  '<|vision_reserved_special_token_845|>': 200931,
#  '<|vision_reserved_special_token_846|>': 200932,
#  '<|vision_reserved_special_token_847|>': 200933,
#  '<|vision_reserved_special_token_848|>': 200934,
#  '<|vision_reserved_special_token_849|>': 200935,
#  '<|vision_reserved_special_token_850|>': 200936,
#  '<|vision_reserved_special_token_851|>': 200937,
#  '<|vision_reserved_special_token_852|>': 200938,
#  '<|vision_reserved_special_token_853|>': 200939,
#  '<|vision_reserved_special_token_854|>': 200940,
#  '<|vision_reserved_special_token_855|>': 200941,
#  '<|vision_reserved_special_token_856|>': 200942,
#  '<|vision_reserved_special_token_857|>': 200943,
#  '<|vision_reserved_special_token_858|>': 200944,
#  '<|vision_reserved_special_token_859|>': 200945,
#  '<|vision_reserved_special_token_860|>': 200946,
#  '<|vision_reserved_special_token_861|>': 200947,
#  '<|vision_reserved_special_token_862|>': 200948,
#  '<|vision_reserved_special_token_863|>': 200949,
#  '<|vision_reserved_special_token_864|>': 200950,
#  '<|vision_reserved_special_token_865|>': 200951,
#  '<|vision_reserved_special_token_866|>': 200952,
#  '<|vision_reserved_special_token_867|>': 200953,
#  '<|vision_reserved_special_token_868|>': 200954,
#  '<|vision_reserved_special_token_869|>': 200955,
#  '<|vision_reserved_special_token_870|>': 200956,
#  '<|vision_reserved_special_token_871|>': 200957,
#  '<|vision_reserved_special_token_872|>': 200958,
#  '<|vision_reserved_special_token_873|>': 200959,
#  '<|vision_reserved_special_token_874|>': 200960,
#  '<|vision_reserved_special_token_875|>': 200961,
#  '<|vision_reserved_special_token_876|>': 200962,
#  '<|vision_reserved_special_token_877|>': 200963,
#  '<|vision_reserved_special_token_878|>': 200964,
#  '<|vision_reserved_special_token_879|>': 200965,
#  '<|vision_reserved_special_token_880|>': 200966,
#  '<|vision_reserved_special_token_881|>': 200967,
#  '<|vision_reserved_special_token_882|>': 200968,
#  '<|vision_reserved_special_token_883|>': 200969,
#  '<|vision_reserved_special_token_884|>': 200970,
#  '<|vision_reserved_special_token_885|>': 200971,
#  '<|vision_reserved_special_token_886|>': 200972,
#  '<|vision_reserved_special_token_887|>': 200973,
#  '<|vision_reserved_special_token_888|>': 200974,
#  '<|vision_reserved_special_token_889|>': 200975,
#  '<|vision_reserved_special_token_890|>': 200976,
#  '<|vision_reserved_special_token_891|>': 200977,
#  '<|vision_reserved_special_token_892|>': 200978,
#  '<|vision_reserved_special_token_893|>': 200979,
#  '<|vision_reserved_special_token_894|>': 200980,
#  '<|vision_reserved_special_token_895|>': 200981,
#  '<|vision_reserved_special_token_896|>': 200982,
#  '<|vision_reserved_special_token_897|>': 200983,
#  '<|vision_reserved_special_token_898|>': 200984,
#  '<|vision_reserved_special_token_899|>': 200985,
#  '<|vision_reserved_special_token_900|>': 200986,
#  '<|vision_reserved_special_token_901|>': 200987,
#  '<|vision_reserved_special_token_902|>': 200988,
#  '<|vision_reserved_special_token_903|>': 200989,
#  '<|vision_reserved_special_token_904|>': 200990,
#  '<|vision_reserved_special_token_905|>': 200991,
#  '<|vision_reserved_special_token_906|>': 200992,
#  '<|vision_reserved_special_token_907|>': 200993,
#  '<|vision_reserved_special_token_908|>': 200994,
#  '<|vision_reserved_special_token_909|>': 200995,
#  '<|vision_reserved_special_token_910|>': 200996,
#  '<|vision_reserved_special_token_911|>': 200997,
#  '<|vision_reserved_special_token_912|>': 200998,
#  '<|vision_reserved_special_token_913|>': 200999,
#  ...}

# %%
len(tokenizer.vocab)
# Out:
# 201135

# %% [markdown]
# # Instruct variants of models
#
# Many models have a variant that has been trained for use in Chats.
# These are typically labelled with the word "Instruct" at the end.
# They have been trained to expect prompts with a particular format that includes system, user and assistant prompts.
#
# There is a utility method `apply_chat_template` that will convert from the messages list format we are familiar with, into the right input prompt for this model.

# %%
tokenizer = AutoTokenizer.from_pretrained('meta-llama/Llama-4-Scout-17B-16E', trust_remote_code=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/237k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/27.9M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/3.62M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/106 [00:00<?, ?B/s]

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Tell a light-hearted joke for a room of Data Scientists"}
  ]

prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
print(prompt)
# Out:
# <|begin_of_text|><|header_start|>system<|header_end|>
#
# You are a helpful assistant<|eot|><|header_start|>user<|header_end|>
#
# Tell a light-hearted joke for a room of Data Scientists<|eot|><|header_start|>assistant<|header_end|>

# %% [markdown]
# ## Crucial "Aha" moment
#
# For 2.5 weeks, I've given you the impression that LLMs could receive a list of python dictionaries in some way:
#
# ```python
# messages = [
#     {"role": "system", "content": "You are a helpful assistant"},
#     {"role": "user", "content": "Tell a light-hearted joke for a room of Data Scientists"}
#   ]
# ```
#
# But an LLM is just a Data Science model that takes a sequence of numbers and predicts the probability of the next number! You can't pass a bunch of Python objects into a statistical model!
#
# ### And now you have the missing piece of the puzzle..
#
# The messages in OpenAI format get converted:
#
# 1. ...into a sequence of words with special tags to separate the System, User, Assistant prompt
# 2. ...then the words are broken down into fragments - "tokens"
# 3. ...then the tokens are replaced with Token IDs - and this is the input sequence
#
# > The input to an LLM is a sequence of Token IDs. The output is the probability distribution of the next Token ID to follow this input.
#
# That's it!

# %% [markdown]
# # Trying new models
#
# We will now work with 3 models:
#
# Phi4 from Microsoft
# DeepSeek 3.1 from DeepSeek AI
# QwenCoder 2.5 from Alibaba Cloud

# %%
PHI4 = "microsoft/Phi-4-mini-instruct"
DEEPSEEK = "deepseek-ai/DeepSeek-V3.1"
QWEN_CODER = "Qwen/Qwen2.5-Coder-7B-Instruct"

# %%
phi4_tokenizer = AutoTokenizer.from_pretrained(PHI4)

text = "I am curiously excited to show Hugging Face Tokenizers in action to my LLM engineers"
print("Llama:")
tokens = tokenizer.encode(text)
print(tokens)
print(tokenizer.batch_decode(tokens))
print("\nPhi 4:")
tokens = phi4_tokenizer.encode(text)
print(tokens)
print(phi4_tokenizer.batch_decode(tokens))
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/15.5M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/249 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/587 [00:00<?, ?B/s]
# Llama:
# [200000, 53, 1045, 3614, 40792, 26095, 328, 2655, 465, 28246, 36110, 19736, 26302, 310, 4245, 328, 1626, 163636, 48556]
# ['<|begin_of_text|>', 'I', ' am', ' cur', 'iously', ' excited', ' to', ' show', ' H', 'ugging', ' Face', ' Token', 'izers', ' in', ' action', ' to', ' my', ' LLM', ' engineers']
#
# Phi 4:
# [40, 939, 4396, 23138, 15209, 316, 2356, 59116, 4512, 29049, 17951, 24223, 306, 3736, 316, 922, 451, 19641, 32437]
# ['I', ' am', ' cur', 'iously', ' excited', ' to', ' show', ' Hug', 'ging', ' Face', ' Token', 'izers', ' in', ' action', ' to', ' my', ' L', 'LM', ' engineers']

# %%
print("Llama:")
print(tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True))
print("\nPhi 4:")
print(phi4_tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True))
# Out:
# Llama:
# <|begin_of_text|><|header_start|>system<|header_end|>
#
# You are a helpful assistant<|eot|><|header_start|>user<|header_end|>
#
# Tell a light-hearted joke for a room of Data Scientists<|eot|><|header_start|>assistant<|header_end|>
#
#
#
# Phi 4:
# <|system|>You are a helpful assistant<|end|><|user|>Tell a light-hearted joke for a room of Data Scientists<|end|><|assistant|>

# %%
deepseek_tokenizer = AutoTokenizer.from_pretrained(DEEPSEEK)

text = "I am curiously excited to show Hugging Face Tokenizers in action to my LLM engineers"
print(tokenizer.encode(text))
print()
print(phi4_tokenizer.encode(text))
print()
print(deepseek_tokenizer.encode(text))
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# [200000, 53, 1045, 3614, 40792, 26095, 328, 2655, 465, 28246, 36110, 19736, 26302, 310, 4245, 328, 1626, 163636, 48556]
#
# [40, 939, 4396, 23138, 15209, 316, 2356, 59116, 4512, 29049, 17951, 24223, 306, 3736, 316, 922, 451, 19641, 32437]
#
# [0, 43, 1030, 108771, 15046, 304, 1801, 24133, 5426, 11906, 47948, 24524, 295, 4271, 304, 1026, 33792, 47, 26170]

# %%
print("Llama:")
print(tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True))
print("\nPhi:")
print(phi4_tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True))
print("\nDeepSeek:")
print(deepseek_tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True))
# Out:
# Llama:
# <|begin_of_text|><|header_start|>system<|header_end|>
#
# You are a helpful assistant<|eot|><|header_start|>user<|header_end|>
#
# Tell a light-hearted joke for a room of Data Scientists<|eot|><|header_start|>assistant<|header_end|>
#
#
#
# Phi:
# <|system|>You are a helpful assistant<|end|><|user|>Tell a light-hearted joke for a room of Data Scientists<|end|><|assistant|>
#
# DeepSeek:
# <｜begin▁of▁sentence｜>You are a helpful assistant<｜User｜>Tell a light-hearted joke for a room of Data Scientists<｜Assistant｜></think>

# %%
qwen_tokenizer = AutoTokenizer.from_pretrained(QWEN_CODER)
code = """
def hello_world(person):
  print("Hello", person)
"""
tokens = qwen_tokenizer.encode(code)
for token in tokens:
  print(f"{token}={qwen_tokenizer.decode(token)}")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# 198=
#
# 750=def
# 23811= hello
# 31792=_world
# 29766=(person
# 982=):
#
# 220=
# 1173= print
# 445=("
# 9707=Hello
# 497=",
# 1697= person
# 340=)
